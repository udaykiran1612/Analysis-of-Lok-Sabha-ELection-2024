# %%
#Importing Libraries

import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Bye-elections data
# #### (Bihar, Haryana, Gujarat, Jharkhand, Maharashtra, Telangana,Tripura, Uttar Pradesh and West Bengal)

# %%
def get_election_data(url, state_name, constituency_name):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    table = soup.find("table", class_="table table-striped table-bordered")

    headers = [header.text.strip() for header in table.find_all('th')]
    desired_headers = ["S.N.", "Candidate", "Party", "EVM Votes", "Postal Votes", "Total Votes", "% of Votes"]
    filtered_headers = [title for title in headers if title in desired_headers]

    rows = []
    for row in table.find_all('tr')[1:]:
        row_data = [cell.text.strip() for cell in row.find_all('td')]
        if len(row_data) == len(filtered_headers):
            rows.append(row_data)

    df = pd.DataFrame(rows, columns=filtered_headers)
    df = df.dropna(how='all')

    df.insert(1, "Constituency", constituency_name)
    df.insert(1, "State", state_name)

    return df

url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS04195.htm"
state_n = "Bihar"
constituency_n = "Agiaon"
df_main = get_election_data(url_n, state_n, constituency_n)

df_main
# Out:
#   S.N.  State Constituency                            Candidate  \
# 0    1  Bihar       Agiaon                    PRABHUNATH PRASAD
# 1    2  Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2    3  Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3    4  Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4    5  Bihar       Agiaon                        PRADEEP KUMAR
# 5    6  Bihar       Agiaon                         BHIKHARI RAM
# 6    7  Bihar       Agiaon                          VIJAY MEHRA
# 7    8  Bihar       Agiaon                       SARASWATI DEVI
# 8    9  Bihar       Agiaon                           SONU KUMAR
# 9   10  Bihar       Agiaon                                 NOTA
#
#                                                Party EVM Votes Postal Votes  \
# 0                               Janata Dal  (United)     43334          291
# 1  Communist Party of India  (Marxist-Leninist)  ...     73191          269
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS0626.htm"
state_n = "Gujarat"
constituency_n = "Vijapur"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.    State Constituency                             Candidate  \
# 0     1    Bihar       Agiaon                     PRABHUNATH PRASAD
# 1     2    Bihar       Agiaon                   SHIV PRAKASH RANJAN
# 2     3    Bihar       Agiaon   UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4    Bihar       Agiaon       UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5    Bihar       Agiaon                         PRADEEP KUMAR
# 5     6    Bihar       Agiaon                          BHIKHARI RAM
# 6     7    Bihar       Agiaon                           VIJAY MEHRA
# 7     8    Bihar       Agiaon                        SARASWATI DEVI
# 8     9    Bihar       Agiaon                            SONU KUMAR
# 9    10    Bihar       Agiaon                                  NOTA
# 10    1  Gujarat      Vijapur                      DR. C. J. CHAVDA
# 11    2  Gujarat      Vijapur            DINESHBHAI TULSIBHAI PATEL
# 12    3  Gujarat      Vijapur          ANKITKUMAR HARSHADBHAI GOHIL
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS0683.htm"
state_n = "Gujarat"
constituency_n = "Porbandar"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.    State Constituency                             Candidate  \
# 0     1    Bihar       Agiaon                     PRABHUNATH PRASAD
# 1     2    Bihar       Agiaon                   SHIV PRAKASH RANJAN
# 2     3    Bihar       Agiaon   UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4    Bihar       Agiaon       UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5    Bihar       Agiaon                         PRADEEP KUMAR
# 5     6    Bihar       Agiaon                          BHIKHARI RAM
# 6     7    Bihar       Agiaon                           VIJAY MEHRA
# 7     8    Bihar       Agiaon                        SARASWATI DEVI
# 8     9    Bihar       Agiaon                            SONU KUMAR
# 9    10    Bihar       Agiaon                                  NOTA
# 10    1  Gujarat      Vijapur                      DR. C. J. CHAVDA
# 11    2  Gujarat      Vijapur            DINESHBHAI TULSIBHAI PATEL
# 12    3  Gujarat      Vijapur          ANKITKUMAR HARSHADBHAI GOHIL
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS0685.htm"
state_n = "Gujarat"
constituency_n = "Manavadar"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.    State Constituency                             Candidate  \
# 0     1    Bihar       Agiaon                     PRABHUNATH PRASAD
# 1     2    Bihar       Agiaon                   SHIV PRAKASH RANJAN
# 2     3    Bihar       Agiaon   UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4    Bihar       Agiaon       UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5    Bihar       Agiaon                         PRADEEP KUMAR
# 5     6    Bihar       Agiaon                          BHIKHARI RAM
# 6     7    Bihar       Agiaon                           VIJAY MEHRA
# 7     8    Bihar       Agiaon                        SARASWATI DEVI
# 8     9    Bihar       Agiaon                            SONU KUMAR
# 9    10    Bihar       Agiaon                                  NOTA
# 10    1  Gujarat      Vijapur                      DR. C. J. CHAVDA
# 11    2  Gujarat      Vijapur            DINESHBHAI TULSIBHAI PATEL
# 12    3  Gujarat      Vijapur          ANKITKUMAR HARSHADBHAI GOHIL
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS06108.htm"
state_n = "Gujarat"
constituency_n = "Khambhat"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.    State Constituency                             Candidate  \
# 0     1    Bihar       Agiaon                     PRABHUNATH PRASAD
# 1     2    Bihar       Agiaon                   SHIV PRAKASH RANJAN
# 2     3    Bihar       Agiaon   UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4    Bihar       Agiaon       UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5    Bihar       Agiaon                         PRADEEP KUMAR
# 5     6    Bihar       Agiaon                          BHIKHARI RAM
# 6     7    Bihar       Agiaon                           VIJAY MEHRA
# 7     8    Bihar       Agiaon                        SARASWATI DEVI
# 8     9    Bihar       Agiaon                            SONU KUMAR
# 9    10    Bihar       Agiaon                                  NOTA
# 10    1  Gujarat      Vijapur                      DR. C. J. CHAVDA
# 11    2  Gujarat      Vijapur            DINESHBHAI TULSIBHAI PATEL
# 12    3  Gujarat      Vijapur          ANKITKUMAR HARSHADBHAI GOHIL
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS06136.htm"
state_n = "Gujarat"
constituency_n = "Vaghodia"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.    State Constituency                             Candidate  \
# 0     1    Bihar       Agiaon                     PRABHUNATH PRASAD
# 1     2    Bihar       Agiaon                   SHIV PRAKASH RANJAN
# 2     3    Bihar       Agiaon   UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4    Bihar       Agiaon       UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5    Bihar       Agiaon                         PRADEEP KUMAR
# 5     6    Bihar       Agiaon                          BHIKHARI RAM
# 6     7    Bihar       Agiaon                           VIJAY MEHRA
# 7     8    Bihar       Agiaon                        SARASWATI DEVI
# 8     9    Bihar       Agiaon                            SONU KUMAR
# 9    10    Bihar       Agiaon                                  NOTA
# 10    1  Gujarat      Vijapur                      DR. C. J. CHAVDA
# 11    2  Gujarat      Vijapur            DINESHBHAI TULSIBHAI PATEL
# 12    3  Gujarat      Vijapur          ANKITKUMAR HARSHADBHAI GOHIL
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS0721.htm"
state_n = "Haryana"
constituency_n = "KARNAL"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.    State Constituency                             Candidate  \
# 0     1    Bihar       Agiaon                     PRABHUNATH PRASAD
# 1     2    Bihar       Agiaon                   SHIV PRAKASH RANJAN
# 2     3    Bihar       Agiaon   UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4    Bihar       Agiaon       UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5    Bihar       Agiaon                         PRADEEP KUMAR
# 5     6    Bihar       Agiaon                          BHIKHARI RAM
# 6     7    Bihar       Agiaon                           VIJAY MEHRA
# 7     8    Bihar       Agiaon                        SARASWATI DEVI
# 8     9    Bihar       Agiaon                            SONU KUMAR
# 9    10    Bihar       Agiaon                                  NOTA
# 10    1  Gujarat      Vijapur                      DR. C. J. CHAVDA
# 11    2  Gujarat      Vijapur            DINESHBHAI TULSIBHAI PATEL
# 12    3  Gujarat      Vijapur          ANKITKUMAR HARSHADBHAI GOHIL
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS0818.htm"
state_n = "Himachal Pradesh"
constituency_n = "DHARAMSHALA"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.             State Constituency                             Candidate  \
# 0     1             Bihar       Agiaon                     PRABHUNATH PRASAD
# 1     2             Bihar       Agiaon                   SHIV PRAKASH RANJAN
# 2     3             Bihar       Agiaon   UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4             Bihar       Agiaon       UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5             Bihar       Agiaon                         PRADEEP KUMAR
# 5     6             Bihar       Agiaon                          BHIKHARI RAM
# 6     7             Bihar       Agiaon                           VIJAY MEHRA
# 7     8             Bihar       Agiaon                        SARASWATI DEVI
# 8     9             Bihar       Agiaon                            SONU KUMAR
# 9    10             Bihar       Agiaon                                  NOTA
# 10    1           Gujarat      Vijapur                      DR. C. J. CHAVDA
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS0821.htm"
state_n = "Himachal Pradesh"
constituency_n = "LAHAUL & SPITI"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.             State    Constituency  \
# 0     1             Bihar          Agiaon
# 1     2             Bihar          Agiaon
# 2     3             Bihar          Agiaon
# 3     4             Bihar          Agiaon
# 4     5             Bihar          Agiaon
# 5     6             Bihar          Agiaon
# 6     7             Bihar          Agiaon
# 7     8             Bihar          Agiaon
# 8     9             Bihar          Agiaon
# 9    10             Bihar          Agiaon
# 10    1           Gujarat         Vijapur
# 11    2           Gujarat         Vijapur
# 12    3           Gujarat         Vijapur
# 13    4           Gujarat         Vijapur
# 14    5           Gujarat         Vijapur
# 15    6           Gujarat         Vijapur
# 16    7           Gujarat         Vijapur
# 17    8           Gujarat         Vijapur
# 18    9           Gujarat         Vijapur
# 19    1           Gujarat       Porbandar
# 20    2           Gujarat       Porbandar
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS0837.htm"
state_n = "Himachal Pradesh"
constituency_n = "SUJANPUR"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.             State Constituency                            Candidate  \
# 0     1             Bihar       Agiaon                    PRABHUNATH PRASAD
# 1     2             Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2     3             Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4             Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5             Bihar       Agiaon                        PRADEEP KUMAR
# ..  ...               ...          ...                                  ...
# 60    3  Himachal Pradesh     SUJANPUR                 RAVINDER SINGH DOGRA
# 61    4  Himachal Pradesh     SUJANPUR                            ANIL RANA
# 62    5  Himachal Pradesh     SUJANPUR                         RAJESH KUMAR
# 63    6  Himachal Pradesh     SUJANPUR                           SHER SINGH
# 64    7  Himachal Pradesh     SUJANPUR                                 NOTA
#
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS0839.htm"
state_n = "Himachal Pradesh"
constituency_n = "BARSAR"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.             State Constituency                            Candidate  \
# 0     1             Bihar       Agiaon                    PRABHUNATH PRASAD
# 1     2             Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2     3             Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4             Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5             Bihar       Agiaon                        PRADEEP KUMAR
# ..  ...               ...          ...                                  ...
# 64    7  Himachal Pradesh     SUJANPUR                                 NOTA
# 65    1  Himachal Pradesh       BARSAR                 INDER DUTT LAKHANPAL
# 66    2  Himachal Pradesh       BARSAR                        SUBHASH CHAND
# 67    3  Himachal Pradesh       BARSAR                        VISHAL SHARMA
# 68    4  Himachal Pradesh       BARSAR                                 NOTA
#
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS0842.htm"
state_n = "Himachal Pradesh"
constituency_n = "GAGRET"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.             State Constituency                            Candidate  \
# 0     1             Bihar       Agiaon                    PRABHUNATH PRASAD
# 1     2             Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2     3             Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4             Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5             Bihar       Agiaon                        PRADEEP KUMAR
# ..  ...               ...          ...                                  ...
# 70    2  Himachal Pradesh       GAGRET                         RAKESH KALIA
# 71    3  Himachal Pradesh       GAGRET                        AMIT VASHISHT
# 72    4  Himachal Pradesh       GAGRET               ASHOK SONKHALA (MIKKI)
# 73    5  Himachal Pradesh       GAGRET                   MANOHAR LAL SHARMA
# 74    6  Himachal Pradesh       GAGRET                                 NOTA
#
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS0845.htm"
state_n = "Himachal Pradesh"
constituency_n = "KUTLEHAR"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.             State Constituency                            Candidate  \
# 0     1             Bihar       Agiaon                    PRABHUNATH PRASAD
# 1     2             Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2     3             Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4             Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5             Bihar       Agiaon                        PRADEEP KUMAR
# ..  ...               ...          ...                                  ...
# 75    1  Himachal Pradesh     KUTLEHAR              DAVINDER KUMAR (BHUTTO)
# 76    2  Himachal Pradesh     KUTLEHAR                 VIVEK SHARMA (VICKU)
# 77    3  Himachal Pradesh     KUTLEHAR                       CHANCHAL SINGH
# 78    4  Himachal Pradesh     KUTLEHAR                        RAJEEV SHARMA
# 79    5  Himachal Pradesh     KUTLEHAR                                 NOTA
#
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS2731.htm"
state_n = "Jharkhand"
constituency_n = "Gandey"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.      State Constituency                            Candidate  \
# 0     1      Bihar       Agiaon                    PRABHUNATH PRASAD
# 1     2      Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2     3      Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4      Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5      Bihar       Agiaon                        PRADEEP KUMAR
# ..  ...        ...          ...                                  ...
# 87    8  Jharkhand       Gandey                       GULAB PD VERMA
# 88    9  Jharkhand       Gandey                   MD. SHABBIR ANSARI
# 89   10  Jharkhand       Gandey                      SHAHADAT ANSARI
# 90   11  Jharkhand       Gandey                      MD. SAYEED ALAM
# 91   12  Jharkhand       Gandey                                 NOTA
#
#                                                 Party EVM Votes Postal Votes  \
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS1036.htm"
state_n = "Karnataka"
constituency_n = "Shorapur"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#    S.N.      State Constituency                            Candidate  \
# 0     1      Bihar       Agiaon                    PRABHUNATH PRASAD
# 1     2      Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2     3      Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3     4      Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4     5      Bihar       Agiaon                        PRADEEP KUMAR
# ..  ...        ...          ...                                  ...
# 94    3  Karnataka     Shorapur                               ASHOKA
# 95    4  Karnataka     Shorapur                            VENUGOPAL
# 96    5  Karnataka     Shorapur                     VENKATAPPA NAYAK
# 97    6  Karnataka     Shorapur                          SHASHIKUMAR
# 98    7  Karnataka     Shorapur                                 NOTA
#
#                                                 Party EVM Votes Postal Votes  \
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS20165.htm"
state_n = "Rajasthan"
constituency_n = "BAGIDORA"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#     S.N.      State Constituency                            Candidate  \
# 0      1      Bihar       Agiaon                    PRABHUNATH PRASAD
# 1      2      Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2      3      Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3      4      Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4      5      Bihar       Agiaon                        PRADEEP KUMAR
# ..   ...        ...          ...                                  ...
# 98     7  Karnataka     Shorapur                                 NOTA
# 99     1  Rajasthan     BAGIDORA                           KAPURSINGH
# 100    2  Rajasthan     BAGIDORA                    SUBHASH TAMBOLIYA
# 101    3  Rajasthan     BAGIDORA                      JAIKRISHN PATEL
# 102    4  Rajasthan     BAGIDORA                                 NOTA
#
#                                                  Party EVM Votes Postal Votes  \
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS22233.htm"
state_n = "Tamil Nadu"
constituency_n = "Vilavancode"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#     S.N.       State Constituency                            Candidate  \
# 0      1       Bihar       Agiaon                    PRABHUNATH PRASAD
# 1      2       Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2      3       Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3      4       Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4      5       Bihar       Agiaon                        PRADEEP KUMAR
# ..   ...         ...          ...                                  ...
# 109    7  Tamil Nadu  Vilavancode                     MANAVAI KANNAN M
# 110    8  Tamil Nadu  Vilavancode                        MOHAN KUMAR M
# 111    9  Tamil Nadu  Vilavancode                       VIJAYA KUMAR C
# 112   10  Tamil Nadu  Vilavancode                             SHAJIN R
# 113   11  Tamil Nadu  Vilavancode                                 NOTA
#
#                                                  Party EVM Votes Postal Votes  \
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS2971.htm"
state_n = "Telangana"
constituency_n = "Secunderabad Cantt"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#     S.N.      State        Constituency                            Candidate  \
# 0      1      Bihar              Agiaon                    PRABHUNATH PRASAD
# 1      2      Bihar              Agiaon                  SHIV PRAKASH RANJAN
# 2      3      Bihar              Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3      4      Bihar              Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4      5      Bihar              Agiaon                        PRADEEP KUMAR
# ..   ...        ...                 ...                                  ...
# 125   12  Telangana  Secunderabad Cantt                       DANDEM RATHNAM
# 126   13  Telangana  Secunderabad Cantt                     NAGARAJU BANDARU
# 127   14  Telangana  Secunderabad Cantt                        M. RAJA HAMSA
# 128   15  Telangana  Secunderabad Cantt                        M. SANJEEVULU
# 129   16  Telangana  Secunderabad Cantt                                 NOTA
#
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS237.htm"
state_n = "Tripura"
constituency_n = "Ramnagar"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#     S.N.      State        Constituency                            Candidate  \
# 0      1      Bihar              Agiaon                    PRABHUNATH PRASAD
# 1      2      Bihar              Agiaon                  SHIV PRAKASH RANJAN
# 2      3      Bihar              Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3      4      Bihar              Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4      5      Bihar              Agiaon                        PRADEEP KUMAR
# ..   ...        ...                 ...                                  ...
# 128   15  Telangana  Secunderabad Cantt                        M. SANJEEVULU
# 129   16  Telangana  Secunderabad Cantt                                 NOTA
# 130    1    Tripura            Ramnagar                       DIPAK MAJUMDER
# 131    2    Tripura            Ramnagar                            RATAN DAS
# 132    3    Tripura            Ramnagar                                 NOTA
#
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS24136.htm"
state_n = "Uttar Pradesh"
constituency_n = "Dadraul"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#     S.N.          State Constituency                            Candidate  \
# 0      1          Bihar       Agiaon                    PRABHUNATH PRASAD
# 1      2          Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2      3          Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3      4          Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4      5          Bihar       Agiaon                        PRADEEP KUMAR
# ..   ...            ...          ...                                  ...
# 139    7  Uttar Pradesh      Dadraul                      ARADHANA MISHRA
# 140    8  Uttar Pradesh      Dadraul                         SMT. KANCHAN
# 141    9  Uttar Pradesh      Dadraul                         DAVESH KUMAR
# 142   10  Uttar Pradesh      Dadraul                          RASHID KHAN
# 143   11  Uttar Pradesh      Dadraul                                 NOTA
#
#                                                  Party EVM Votes Postal Votes  \
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS24173.htm"
state_n = "Uttar Pradesh"
constituency_n = "Lucknow East"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#     S.N.          State  Constituency                            Candidate  \
# 0      1          Bihar        Agiaon                    PRABHUNATH PRASAD
# 1      2          Bihar        Agiaon                  SHIV PRAKASH RANJAN
# 2      3          Bihar        Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3      4          Bihar        Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4      5          Bihar        Agiaon                        PRADEEP KUMAR
# ..   ...            ...           ...                                  ...
# 144    1  Uttar Pradesh  Lucknow East                        ALOK KUSHWAHA
# 145    2  Uttar Pradesh  Lucknow East                 MUKESH SINGH CHAUHAN
# 146    3  Uttar Pradesh  Lucknow East                     O. P. SRIVASTAVA
# 147    4  Uttar Pradesh  Lucknow East                  VINOD KUMAR BALMIKI
# 148    5  Uttar Pradesh  Lucknow East                                 NOTA
#
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS24292.htm"
state_n = "Uttar Pradesh"
constituency_n = "Gainsari"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#     S.N.          State Constituency                            Candidate  \
# 0      1          Bihar       Agiaon                    PRABHUNATH PRASAD
# 1      2          Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2      3          Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3      4          Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4      5          Bihar       Agiaon                        PRADEEP KUMAR
# ..   ...            ...          ...                                  ...
# 152    4  Uttar Pradesh     Gainsari                    MOHD GULJAR AHMAD
# 153    5  Uttar Pradesh     Gainsari                           RAM DULARE
# 154    6  Uttar Pradesh     Gainsari                         LAKSHMAN LAL
# 155    7  Uttar Pradesh     Gainsari                             SHESHRAM
# 156    8  Uttar Pradesh     Gainsari                                 NOTA
#
#                                                  Party EVM Votes Postal Votes  \
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS24403.htm"
state_n = "Uttar Pradesh"
constituency_n = "Duddhi"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#     S.N.          State Constituency                            Candidate  \
# 0      1          Bihar       Agiaon                    PRABHUNATH PRASAD
# 1      2          Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2      3          Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3      4          Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4      5          Bihar       Agiaon                        PRADEEP KUMAR
# ..   ...            ...          ...                                  ...
# 159    3  Uttar Pradesh       Duddhi                        SARAVAN KUMAR
# 160    4  Uttar Pradesh       Duddhi                    DAYASHANKAR SINGH
# 161    5  Uttar Pradesh       Duddhi                          MANOJ KUMAR
# 162    6  Uttar Pradesh       Duddhi                         DINESH KUMAR
# 163    7  Uttar Pradesh       Duddhi                                 NOTA
#
#                                                  Party EVM Votes Postal Votes  \
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS2562.htm"
state_n = "West Bengal"
constituency_n = "Bhagabangola"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#     S.N.        State  Constituency                            Candidate  \
# 0      1        Bihar        Agiaon                    PRABHUNATH PRASAD
# 1      2        Bihar        Agiaon                  SHIV PRAKASH RANJAN
# 2      3        Bihar        Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3      4        Bihar        Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4      5        Bihar        Agiaon                        PRADEEP KUMAR
# ..   ...          ...           ...                                  ...
# 167    4  West Bengal  Bhagabangola                  OMAR KHAYYAM (ZIKO)
# 168    5  West Bengal  Bhagabangola                    MD MURSHIDUL ALAM
# 169    6  West Bengal  Bhagabangola                       NASHIM HOSSAIN
# 170    7  West Bengal  Bhagabangola                      MD. NURUL ISLAM
# 171    8  West Bengal  Bhagabangola                                 NOTA
#
#                                                  Party EVM Votes Postal Votes  \
# ...

# %%
url_n = "https://results.eci.gov.in/AcResultByeJune2024/ConstituencywiseS25113.htm"
state_n = "West Bengal"
constituency_n = "Baranagar"
df_new = get_election_data(url_n, state_n, constituency_n)

df_main = pd.concat([df_main, df_new], ignore_index=True)
df_main
# Out:
#     S.N.        State Constituency                            Candidate  \
# 0      1        Bihar       Agiaon                    PRABHUNATH PRASAD
# 1      2        Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2      3        Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3      4        Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4      5        Bihar       Agiaon                        PRADEEP KUMAR
# ..   ...          ...          ...                                  ...
# 176    5  West Bengal    Baranagar                 SAMAR KRISHNA SINGHA
# 177    6  West Bengal    Baranagar                        PRASENJIT DEY
# 178    7  West Bengal    Baranagar                  SHUBHRANGSHU BHAKTA
# 179    8  West Bengal    Baranagar                    SAJAL KUMAR GHOSH
# 180    9  West Bengal    Baranagar                                 NOTA
#
#                                                  Party EVM Votes Postal Votes  \
# ...

# %%
df_main.drop(columns=['S.N.'], inplace=True)
df_main
# Out:
#            State Constituency                            Candidate  \
# 0          Bihar       Agiaon                    PRABHUNATH PRASAD
# 1          Bihar       Agiaon                  SHIV PRAKASH RANJAN
# 2          Bihar       Agiaon  UPENDRA KUMAR S/O - CHANDESHWAR RAM
# 3          Bihar       Agiaon      UPENDRA KUMAR S/O- VAIJNATH RAM
# 4          Bihar       Agiaon                        PRADEEP KUMAR
# ..           ...          ...                                  ...
# 176  West Bengal    Baranagar                 SAMAR KRISHNA SINGHA
# 177  West Bengal    Baranagar                        PRASENJIT DEY
# 178  West Bengal    Baranagar                  SHUBHRANGSHU BHAKTA
# 179  West Bengal    Baranagar                    SAJAL KUMAR GHOSH
# 180  West Bengal    Baranagar                                 NOTA
#
#                                                  Party EVM Votes Postal Votes  \
# 0                                 Janata Dal  (United)     43334          291
# ...

# %%
df_main.to_csv("By_elections_data.csv", index=False)
